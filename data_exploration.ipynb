# %%
import pandas as pd
import numpy as np

df= pd.read_excel('d360_dataset.xlsx')
df

# %%
df
# Out:
#            REPORTNO SHAPE  WEIGHT CUT POLISH SYMN COLOR PURITY FLUOR  MES1  \
# 0      3.365985e+09    RD    0.58   X      X    X     D     IF     N  5.40
# 1      2.386810e+09    RD    0.50   X      X    X     D     IF     N  5.07
# 2      1.385366e+09    RD    0.50   X      X    X     D     IF     N  5.17
# 3      6.382727e+09    RD    0.55   X      X    X     D     IF     N  5.28
# 4      7.383727e+09    RD    0.57   X      X    X     D     IF     N  5.30
# ...             ...   ...     ...  ..    ...  ...   ...    ...   ...   ...
# 18672  1.210260e+09   RBC    1.58   X      X    X     J    SI1     N  7.38
# 18673  5.210190e+09   RBC    1.63   X      X    X     J    SI1     N  7.46
# 18674  2.446780e+09   RBC    1.70   X      X    X     J    SI1     N  7.60
# 18675  7.210280e+09   RBC    1.70   X      X    X     J    SI1     F  7.62
# 18676  9.873940e+09   RBC    1.80   X      X    X     J    SI1     N  7.67
#
#        ...  COMPANY ID  RATIO  CERT  RAP PRICE PER CARAT  \
# ...
